# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys

# %%
df = pd.read_csv('duplicate_counts.csv')

df.columns = ['no', 'id', 'flags', 'ref', 'for_pos', 'qual', 'cigar', 'paired', 'rev_pos', 'length', 'for_count', 'rev_count']

df
# Out:
#           no                  id  flags       ref  for_pos  qual   cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60    138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60    138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60    138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60  130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60    138M
# ...      ...                 ...    ...       ...      ...   ...     ...
# 86578  86578  SRR10199716.167750   1171  U00096.3  4635048    60    138M
# 86579  86579   SRR10199716.59475   1171  U00096.3  4635048    60    138M
# 86580  86580  SRR10199716.652277   1171  U00096.3  4635048    60    138M
# 86581  86581  SRR10199716.118008   1171  U00096.3  4635048    60    138M
# 86582  86582  SRR10199716.451516   1171  U00096.3  4635051    60  3S135M
#
#       paired  rev_pos  length  for_count  rev_count
# 0          =     3713     507          6          6
# 1          =     3713     507          6          6
# 2          =     3713     507          6          6
# 3          =     3713     507          6          6
# 4          =     3713     507          6          6
# ...      ...      ...     ...        ...        ...
# 86578      =  4634943    -243         31         33
# 86579      =  4634943    -243         31         33
# 86580      =  4634943    -243         31         33
# 86581      =  4634943    -243         31         33
# 86582      =  4634943    -243          1         33
#
# [86583 rows x 12 columns]

# %%
df['abs_length'] = df['length'].abs()
df = df.loc[df['abs_length'] < 5000]
df.reset_index(inplace=True, drop=True)
# df['with_adapt'] = df['abs_length'] + 0
df['counts'] = df.groupby(['id'])['abs_length'].transform('count')

df
# Out:
# <ipython-input-3-5d315b530605>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['counts'] = df.groupby(['id'])['abs_length'].transform('count')
#           no                  id  flags       ref  for_pos  qual   cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60    138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60    138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60    138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60  130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60    138M
# ...      ...                 ...    ...       ...      ...   ...     ...
# 86570  86578  SRR10199716.167750   1171  U00096.3  4635048    60    138M
# 86571  86579   SRR10199716.59475   1171  U00096.3  4635048    60    138M
# 86572  86580  SRR10199716.652277   1171  U00096.3  4635048    60    138M
# 86573  86581  SRR10199716.118008   1171  U00096.3  4635048    60    138M
# 86574  86582  SRR10199716.451516   1171  U00096.3  4635051    60  3S135M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts
# 0          =     3713     507          6          6         507       2
# 1          =     3713     507          6          6         507       2
# 2          =     3713     507          6          6         507       2
# 3          =     3713     507          6          6         507       2
# 4          =     3713     507          6          6         507       2
# ...      ...      ...     ...        ...        ...         ...     ...
# 86570      =  4634943    -243         31         33         243       2
# 86571      =  4634943    -243         31         33         243       2
# 86572      =  4634943    -243         31         33         243       2
# 86573      =  4634943    -243         31         33         243       2
# 86574      =  4634943    -243          1         33         243       2
#
# [86575 rows x 14 columns]

# %%
tmp_df = df[df['counts'] > 2]
tmp_df
# Out:
#           no                  id  flags       ref  for_pos  qual      cigar  \
# 3672    3673  SRR10199716.631758   3171  U00096.3   224445     0     59M75H
# 4610    4611  SRR10199716.631758   1123  U00096.3   224534     0     89S45M
# 4632    4633  SRR10199716.631758   1171  U00096.3   224534     0  29S58M51S
# 52212  52218  SRR10199716.606725   2147  U00096.3  3094061    49  20H32M82H
# 52213  52219  SRR10199716.606725     99  U00096.3  3094094    49     75S59M
# 52214  52220  SRR10199716.606725    147  U00096.3  3094106    60     5S133M
# 65681  65689  SRR10199716.654148     99  U00096.3  3879587    60  12S95M27S
# 65683  65691  SRR10199716.654148    147  U00096.3  3879614    60     68M70S
# 65685  65693  SRR10199716.654148   2195  U00096.3  3879710    58     96H42M
# 70200  70208  SRR10199716.592886   3171  U00096.3  4016810    60     39M95H
# 70283  70291  SRR10199716.592886   1171  U00096.3  4016834    60       138M
# 70328  70336  SRR10199716.592886   1123  U00096.3  4016876    60     66S68M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts
# 3672       =   224534     147        489        160         147       3
# 4610       =   224534      58        159        160          58       3
# 4632       =   224534     -58        159        160          58       3
# 52212      =  3094106     178          1          2         178       3
# 52213      =  3094106     145          1          2         145       3
# 52214      =  3094094    -145          1          1         145       3
# 65681      =  3879614      95          2          2          95       3
# 65683      =  3879587     -95          2          3          95       3
# 65685      =  3879587    -165          1          3         165       3
# 70200      =  4016834     162         73         68         162       3
# 70283      =  4016876     -96         67          1          96       3
# 70328      =  4016834      96          1         68          96       3

# %%
df = df[df['counts'] == 2]

tmp_df.reset_index(inplace=True, drop=True)

for_removal = []

for i in range(tmp_df.shape[0]):
    very_tmp = tmp_df[tmp_df['id'] == tmp_df.iloc[i]['id']]
    if very_tmp[very_tmp['abs_length'] == tmp_df.iloc[i]['abs_length']].shape[0] != 2:
        for_removal.append(i)
        
tmp_df.drop(for_removal, inplace=True)
df = pd.concat([df, tmp_df], axis=0)
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.reset_index(inplace=True, drop=True)

df = df[df['length'] > 0]
df
# Out:
#           no                  id  flags       ref  for_pos  qual      cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60       138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60       138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60       138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60     130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60       138M
# ...      ...                 ...    ...       ...      ...   ...        ...
# 86527  86548  SRR10199716.118008   1123  U00096.3  4634943    60       134M
# 86562   4611  SRR10199716.631758   1123  U00096.3   224534     0     89S45M
# 86564  52219  SRR10199716.606725     99  U00096.3  3094094    49     75S59M
# 86566  65689  SRR10199716.654148     99  U00096.3  3879587    60  12S95M27S
# 86569  70336  SRR10199716.592886   1123  U00096.3  4016876    60     66S68M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts
# 0          =     3713     507          6          6         507       2
# 1          =     3713     507          6          6         507       2
# 2          =     3713     507          6          6         507       2
# 3          =     3713     507          6          6         507       2
# 4          =     3713     507          6          6         507       2
# ...      ...      ...     ...        ...        ...         ...     ...
# 86527      =  4635048     243         33         31         243       2
# 86562      =   224534      58        159        160          58       3
# 86564      =  3094106     145          1          2         145       3
# 86566      =  3879614      95          2          2          95       3
# 86569      =  4016834      96          1         68          96       3
#
# [43285 rows x 14 columns]

# %%
for_ls = df['for_pos'].unique().tolist()
rev_ls = df['rev_pos'].unique().tolist()

# %%
window = 10

mark_dt = {}
for i in for_ls:
    mark = i
    target = df[df['for_pos'] == i].shape[0]
    for j in range(i - window, i + window):
        if df[df['for_pos'] == j].shape[0] > target:
            target = df[df['for_pos'] == j].shape[0]
            mark = j
    mark_dt[i] = mark
df['for_mark'] = df['for_pos'].map(mark_dt)


mark_dt = {}
for i in rev_ls:
    mark = i
    target = df[df['rev_pos'] == i].shape[0]
    for j in range(i - window, i + window):
        if df[df['rev_pos'] == j].shape[0] > target:
            target = df[df['rev_pos'] == j].shape[0]
            mark = j
    mark_dt[i] = mark
df['rev_mark'] = df['rev_pos'].map(mark_dt)

# %%
df = df[(df['for_pos'] == df['for_mark']) & (df['rev_pos'] == df['rev_mark'])]
df
# Out:
#           no                  id  flags       ref  for_pos  qual      cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60       138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60       138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60       138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60     130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60       138M
# ...      ...                 ...    ...       ...      ...   ...        ...
# 86526  86547  SRR10199716.652277   1123  U00096.3  4634943    60       134M
# 86527  86548  SRR10199716.118008   1123  U00096.3  4634943    60       134M
# 86564  52219  SRR10199716.606725     99  U00096.3  3094094    49     75S59M
# 86566  65689  SRR10199716.654148     99  U00096.3  3879587    60  12S95M27S
# 86569  70336  SRR10199716.592886   1123  U00096.3  4016876    60     66S68M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts  \
# 0          =     3713     507          6          6         507       2
# 1          =     3713     507          6          6         507       2
# 2          =     3713     507          6          6         507       2
# 3          =     3713     507          6          6         507       2
# 4          =     3713     507          6          6         507       2
# ...      ...      ...     ...        ...        ...         ...     ...
# 86526      =  4635048     243         33         31         243       2
# 86527      =  4635048     243         33         31         243       2
# 86564      =  3094106     145          1          2         145       3
# 86566      =  3879614      95          2          2          95       3
# 86569      =  4016834      96          1         68          96       3
#
#        for_mark  rev_mark
# 0          3340      3713
# 1          3340      3713
# 2          3340      3713
# 3          3340      3713
# 4          3340      3713
# ...         ...       ...
# 86526   4634943   4635048
# 86527   4634943   4635048
# 86564   3094094   3094106
# 86566   3879587   3879614
# 86569   4016876   4016834
#
# [39409 rows x 16 columns]

# %%
df['for_mark'] = df['for_mark'].map(str)
df['rev_mark'] = df['rev_mark'].map(str)
df['unique_id'] = df['for_mark'] + '_' + df['rev_mark']
df
# Out:
# <ipython-input-10-a20f932021ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['for_mark'] = df['for_mark'].map(str)
# <ipython-input-10-a20f932021ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rev_mark'] = df['rev_mark'].map(str)
# <ipython-input-10-a20f932021ac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unique_id'] = df['for_mark'] + '_' + df['rev_mark']
#           no                  id  flags       ref  for_pos  qual      cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60       138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60       138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60       138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60     130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60       138M
# ...      ...                 ...    ...       ...      ...   ...        ...
# 86526  86547  SRR10199716.652277   1123  U00096.3  4634943    60       134M
# 86527  86548  SRR10199716.118008   1123  U00096.3  4634943    60       134M
# 86564  52219  SRR10199716.606725     99  U00096.3  3094094    49     75S59M
# 86566  65689  SRR10199716.654148     99  U00096.3  3879587    60  12S95M27S
# 86569  70336  SRR10199716.592886   1123  U00096.3  4016876    60     66S68M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts  \
# 0          =     3713     507          6          6         507       2
# 1          =     3713     507          6          6         507       2
# 2          =     3713     507          6          6         507       2
# 3          =     3713     507          6          6         507       2
# 4          =     3713     507          6          6         507       2
# ...      ...      ...     ...        ...        ...         ...     ...
# 86526      =  4635048     243         33         31         243       2
# 86527      =  4635048     243         33         31         243       2
# 86564      =  3094106     145          1          2         145       3
# 86566      =  3879614      95          2          2          95       3
# 86569      =  4016834      96          1         68          96       3
#
#       for_mark rev_mark        unique_id
# 0         3340     3713        3340_3713
# 1         3340     3713        3340_3713
# 2         3340     3713        3340_3713
# 3         3340     3713        3340_3713
# 4         3340     3713        3340_3713
# ...        ...      ...              ...
# 86526  4634943  4635048  4634943_4635048
# 86527  4634943  4635048  4634943_4635048
# 86564  3094094  3094106  3094094_3094106
# 86566  3879587  3879614  3879587_3879614
# 86569  4016876  4016834  4016876_4016834
#
# [39409 rows x 17 columns]

# %%
length_dt = {i: [] for i in df['abs_length'].unique().tolist()}

# %%
loci_ls = df['unique_id'].unique().tolist()

# %%
window = 10

final_df = pd.DataFrame()
avgs_dt = {}
mark_dt = {}

for i in loci_ls:
    tmp_df = df[(df['unique_id'] == i)]
    tmp_dt = tmp_df['abs_length'].value_counts().to_frame().to_dict()['abs_length']
    target = max(tmp_dt, key=tmp_dt.get)
    tmp_df = tmp_df[tmp_df['abs_length'].between(target - window, target + window)]
    tmp_df['abs_length'] = target
    final_df = pd.concat([final_df, tmp_df], axis=0)
    if target in avgs_dt:
        avgs_dt[target].append(tmp_df.shape[0])
    else:
        avgs_dt[target] = [tmp_df.shape[0]]

# %%
avgs_dt
# Out:
# {507: [6, 8],
#  210: [41, 42, 1, 17, 57],
#  211: [1, 27],
#  300: [3, 1, 1],
#  242: [1, 1, 29, 46],
#  294: [20, 2, 37],
#  117: [45, 3, 59, 1, 1, 31],
#  225: [2, 2, 31, 38, 21, 37, 65],
#  299: [1, 55, 1, 56, 1, 1],
#  298: [1, 12, 1, 1, 1, 1],
#  297: [1, 28, 2, 1, 1, 1, 56, 66, 1, 83, 1],
#  267: [1, 62, 2, 2, 27],
#  472: [27],
#  202: [3, 67, 4],
#  377: [1, 1],
#  100: [2, 43, 1, 2],
#  69: [26, 20, 19, 36, 1, 20, 20, 1, 31, 1, 1],
#  78: [1, 22, 3, 21, 20, 1, 22, 12],
#  104: [1, 28, 1, 1, 1, 1, 26],
#  43: [1, 61, 12, 1, 19, 8, 1, 47, 17, 43, 46, 54, 8],
#  313: [5],
#  145: [48, 32, 1, 1],
#  50: [1, 28, 1, 4, 15, 25, 1],
#  366: [33, 17, 26, 1],
#  321: [1, 33],
#  320: [1, 1, 78, 1],
#  317: [1, 27, 1],
#  154: [1, 1],
#  219: [68, 1, 1, 1],
#  209: [1, 46, 1, 31, 2, 1, 69, 1, 1, 1],
#  73: [1, 23, 1, 1, 30, 18, 15, 34],
#  22: [1, 47, 1, 7, 2, 1, 1, 1],
#  33: [1, 8, 1, 2, 1, 18, 8],
#  74: [1, 11, 7, 21, 14],
#  96: [14, 41, 9, 1, 31, 20, 16, 30, 25, 15, 25, 1, 1],
#  75: [15, 54, 1, 18, 1, 32, 1, 20, 1, 14, 1, 46, 1, 15, 10],
#  357: [33, 1, 1, 1],
#  287: [1, 20, 1, 1],
#  93: [19, 14, 30, 1, 44, 2, 13, 22, 29],
#  172: [54, 81, 1, 18, 1, 2, 1, 63],
#  101: [1, 39, 1, 5, 1, 18, 35],
#  291: [21, 19, 67, 36],
#  404: [39, 12],
#  311: [1],
#  128: [26],
#  675: [1],
#  326: [50, 1, 13, 1],
#  274: [1, 1, 1],
#  165: [30, 16, 65, 44, 1, 1, 1, 1, 56],
#  543: [15, 1, 17, 1, 1, 1],
#  169: [1, 1, 134, 1, 1],
#  231: [88, 20, 1, 27, 66, 29],
#  111: [38, 1, 1, 1, 59, 1, 1, 1, 81, 1, 28, 1, 49],
#  41: [21, 1, 1, 10, 11, 1, 23],
#  26: [1, 3],
#  195: [26, 1, 1, 2, 1, 53, 71, 1, 42, 1, 92, 1, 1, 85, 72, 58, 64, 63],
#  76: [1, 17, 2, 1, 6, 1, 1, 1, 11, 28],
#  611: [1],
#  621: [3, 11, 1],
#  318: [1, 41, 33],
#  127: [1],
#  261: [4, 28, 1, 1, 1],
#  159: [105, 1, 38, 1, 1, 1, 1, 59, 1],
#  105: [1, 35, 1, 1, 1, 30, 14, 28, 28, 1, 1, 1],
#  21: [1,
#   2,
#   3,
#   3,
#   159,
#   1,
#   1,
#   1,
#   29,
#   3,
#   3,
#   2,
#   64,
#   3,
#   2,
#   33,
#   1,
#   19,
#   1,
#   1,
#   1,
#   37,
#   4,
#   1],
#  244: [2, 82, 1, 1, 3],
#  180: [1, 1, 53, 1, 29, 1, 80, 1, 24, 1, 68, 1, 1, 1, 1, 43, 1],
#  71: [1, 19, 1, 33, 1, 31, 1, 1, 1, 36],
#  20: [2,
#   95,
#   1,
#   1,
#   4,
#   13,
#   1,
#   69,
#   1,
#   1,
#   1,
#   45,
#   1,
#   94,
#   1,
#   1,
#   1,
#   31,
#   20,
#   29,
#   1,
#   42,
#   1,
#   24,
#   1,
#   1,
#   1,
#   1,
#   2,
#   1,
#   30,
#   1,
#   48,
#   42,
#   1,
#   1,
#   51,
#   13,
#   35,
#   1,
#   1,
#   1,
#   3],
#  62: [1, 2, 35, 27, 12, 1, 2, 1, 1],
#  31: [11, 12, 24, 9, 8, 1],
#  254: [50, 1, 2],
#  245: [2, 1],
#  156: [2, 1, 1, 43, 1, 6, 1, 1],
#  25: [1, 5, 1, 1, 1, 3, 5, 1, 5],
#  166: [7, 60, 1, 34, 1, 38, 66, 1],
#  42: [10, 17, 1, 16, 1, 14, 15, 2, 20, 25],
#  316: [34, 1, 1, 1],
#  54: [19, 1, 8, 8, 1, 18, 14, 19, 1, 20, 34],
#  201: [51, 40, 74, 1, 61, 1],
#  222: [59, 1, 16, 1, 74, 1, 2, 1],
#  331: [1, 42, 1],
#  564: [1],
#  578: [4, 1, 1],
#  83: [1, 1, 21, 1, 17, 1],
#  34: [22, 4, 15, 20, 35, 27, 1, 8, 19, 1, 21, 22, 15, 17, 63, 4, 19],
#  284: [39,
#   1,
#   25,
#   1,
#   65,
#   1,
#   59,
#   1,
#   1,
#   28,
#   32,
#   5,
#   30,
#   3,
#   29,
#   38,
#   3,
#   1,
#   1,
#   44,
#   5,
#   16],
#  147: [140,
#   127,
#   1,
#   44,
#   1,
#   314,
#   1,
#   2,
#   1,
#   325,
#   1,
#   111,
#   141,
#   124,
#   146,
#   1,
#   147,
#   120,
#   107,
#   126,
#   1],
#  198: [64, 82, 1, 3, 58, 58, 66, 53, 54, 70, 76, 1, 72, 1, 45],
#  19: [1,
#   1,
#   1,
#   1,
#   1,
#   28,
#   22,
#   1,
#   1,
#   12,
#   49,
#   1,
#   1,
#   16,
#   1,
#   1,
#   1,
#   15,
#   15,
#   1,
#   1,
#   34,
#   4,
#   57,
#   24,
#   5,
#   1,
#   32,
#   2,
#   1,
#   3,
#   1,
#   1,
#   9,
#   1,
#   1,
#   1,
#   1,
#   20,
#   1,
#   29,
#   34,
#   1,
#   1,
#   16,
#   1,
#   1,
#   48,
#   46,
#   1,
#   28,
#   1,
#   3,
#   1,
#   109,
#   45,
#   19,
#   1,
#   1,
#   1,
#   1,
#   18,
#   11,
#   1,
#   98,
#   14,
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   18,
#   1,
#   1,
#   2,
#   1,
#   26,
#   23,
#   2,
#   1,
#   12,
#   1,
#   1,
#   15,
#   1,
#   42,
#   1,
#   1,
#   4,
#   13,
#   1,
#   1,
#   15],
#  333: [10, 7, 56, 9, 9, 9, 9, 8, 1],
#  60: [44, 3, 23, 1, 7, 15, 50, 52, 18, 50, 5, 2, 41, 13, 1, 63, 5, 64, 5, 13],
#  40: [3, 1, 1, 5, 16, 28, 5, 14, 1, 32, 34, 1, 2],
#  38: [14, 1, 18, 6, 21, 20, 27, 26, 15, 2],
#  27: [1, 8, 1, 1, 10, 1, 2, 15, 1, 7, 2],
#  70: [23, 14, 15, 20, 30, 33, 1, 18, 20, 18, 18],
#  90: [2, 11, 1, 32, 1, 19, 1, 1, 1, 1, 5, 2, 2, 43],
#  92: [25, 1, 31, 1, 14, 26, 17, 1, 3],
#  434: [10, 22, 13],
#  119: [26, 14, 48, 1, 11, 46, 77, 44, 1, 1, 38, 2, 1, 37, 36],
#  234: [57, 1, 1],
#  44: [33, 1, 20, 1, 1, 1, 1, 4],
#  51: [1, 21, 1, 1, 1, 16, 1, 15],
#  85: [17, 17, 1, 25, 26, 13, 1, 14, 1, 3],
#  115: [44, 56, 1, 55, 2, 53, 54, 1],
#  109: [1, 1, 1, 1, 29],
#  251: [56, 1, 17],
#  177: [1, 74, 1, 1, 17, 83, 82, 72, 59, 1, 65, 1, 77, 68, 1, 1, 52, 1],
#  239: [18, 1],
#  89: [24, 15, 10, 1, 7, 9, 1],
#  146: [75, 1, 1, 1, 20, 1, 37, 1, 1],
#  188: [1, 1, 39, 48, 1, 1],
#  148: [38, 94, 1, 1, 4],
#  57: [10, 1, 2, 18, 16, 11, 1, 19, 1, 23, 1],
#  369: [48],
#  340: [1, 1, 1, 1, 1],
#  293: [1, 1],
#  49: [18, 23, 23, 1, 7, 31, 1, 1, 1],
#  240: [42, 1, 72],
#  97: [14, 12, 1, 1, 2],
#  392: [1],
#  396: [25, 1, 1, 1, 1, 22],
#  510: [1],
#  391: [1, 25],
#  303: [43, 1, 62],
#  281: [1, 1, 1],
#  259: [1, 1, 23],
#  176: [20, 1, 1],
#  186: [109, 1, 19, 66, 1, 1, 63, 1, 1, 2, 1],
#  150: [1, 29, 3, 35, 66],
#  133: [1, 16, 1, 2, 2],
#  140: [1],
#  91: [1, 26, 1, 1, 9],
#  295: [59, 1, 49, 1],
#  461: [20, 1, 1, 23],
#  55: [16, 26, 1, 5],
#  356: [30],
#  270: [1, 81],
#  484: [1],
#  310: [8, 6, 1],
#  279: [1, 3, 44, 1, 1, 1, 1],
#  252: [21, 1],
#  196: [1, 1, 5, 34, 1, 1, 1],
#  353: [60],
#  45: [1, 15, 1, 21, 18, 2, 27],
#  58: [14, 18, 2, 20, 21, 11, 13, 1, 1],
#  161: [1, 22, 20, 1, 20, 20],
#  277: [1, 48, 1, 2, 44, 1],
#  372: [1, 35, 39],
#  400: [1],
#  84: [1, 33, 13, 22, 15, 31, 40, 1],
#  588: [1, 1],
#  108: [49, 1, 52, 53, 27, 37, 72, 28, 1, 27, 28, 30, 1],
#  549: [10],
#  324: [10, 1, 1, 2, 53, 1],
#  233: [46, 2, 1, 1],
#  167: [1, 1, 51, 1, 61],
#  690: [2, 1, 1],
#  373: [42],
#  358: [1],
#  257: [1, 47, 1],
#  606: [4, 1, 3],
#  123: [31, 12, 56, 1, 63, 34, 18, 1, 46, 57, 74, 1],
#  30: [8, 14, 6, 1, 1, 10, 2, 3, 1, 1, 9],
#  135: [72, 1, 52, 1, 47, 8, 45],
#  329: [43, 22, 1],
#  280: [1, 42, 34, 1, 75, 1],
#  121: [53, 2, 1, 1, 21, 2],
#  68: [1, 22, 1, 3, 1],
#  182: [1, 68, 1, 39, 1, 31, 1, 41],
#  531: [9, 15, 1, 10],
#  224: [79, 38, 60, 18, 50, 14, 1, 1],
#  191: [1, 40, 76, 1, 58, 1],
#  192: [1, 47, 2, 1],
#  151: [1, 49, 2, 2, 1],
#  65: [1, 19, 1],
#  212: [70, 1, 85, 1, 1, 59],
#  265: [3, 77, 49, 1, 1, 1, 1],
#  283: [2, 27],
#  98: [37, 2],
#  29: [3, 1, 1, 3, 14, 7, 16, 1, 1, 9, 1, 1],
#  39: [6, 19, 24, 25, 6, 14, 20],
#  204: [1, 44, 1, 1, 35, 1, 61, 1, 1, 37, 41],
#  28: [1, 1, 10, 10, 17],
#  124: [1, 1, 3, 61, 62, 1, 1, 72],
#  478: [23, 10, 25],
#  106: [14, 10, 18, 1, 15, 14, 1, 13, 16, 1, 13, 11, 14],
#  427: [1],
#  129: [56, 1, 1, 1, 1, 56, 73, 1, 1],
#  107: [18, 1, 1, 1, 25, 45, 1, 8, 8, 25, 44, 1, 29, 1],
#  189: [49, 1, 1, 1, 1, 24, 85, 32, 1, 38],
#  61: [6, 36, 1, 6, 1, 1, 1, 5],
#  144: [58, 1, 68, 1, 51, 1],
#  82: [1, 28, 1, 1, 1, 1, 1, 23, 15, 25, 1],
#  409: [25, 1],
#  395: [1],
#  382: [1, 1, 1],
#  423: [2, 46, 1],
#  72: [1, 35, 36, 1, 23, 8, 27, 1, 16, 24, 14, 1, 25, 1],
#  52: [13, 1, 11, 12, 21, 1, 39, 19],
#  173: [90, 19, 1, 1, 54, 1, 91, 46, 1, 40],
#  207: [80, 2, 49, 1, 5, 64],
#  290: [65, 24, 69],
#  95: [77, 1, 1, 1, 17, 35, 1, 33, 1, 1],
#  116: [62, 37, 1, 34, 1, 1, 1, 1, 1],
#  66: [8, 24, 9, 8, 1, 1, 17, 14, 1],
#  35: [4, 10, 2, 1, 11, 1],
#  237: [38, 2, 1, 36],
#  627: [5, 1, 4],
#  276: [1, 36, 1, 1],
#  249: [33, 58, 1],
#  565: [2, 5, 1],
#  37: [1, 1, 14, 11, 12, 27],
#  163: [3, 29, 50, 1, 1, 49, 1],
#  67: [2, 9, 1, 9],
#  47: [21, 1, 1, 23, 20],
#  410: [48, 1],
#  332: [1],
#  381: [54, 13, 1, 12],
#  335: [1],
#  526: [12, 4],
#  258: [13, 86, 2, 1, 1, 40, 46],
#  438: [26, 31],
#  432: [1, 8],
#  250: [73, 1, 41, 1],
#  483: [2, 11],
#  63: [3, 23, 14, 20, 1, 1, 10, 22, 13, 25, 15],
#  671: [4],
#  650: [1],
#  79: [18, 37, 29, 12, 61, 18],
#  264: [1, 43, 1, 1, 11, 2, 7, 57],
#  187: [8, 22, 28, 1],
#  443: [10, 1, 20, 17],
#  248: [1, 57, 48, 1],
#  59: [14, 28, 1, 1, 20, 1],
#  599: [9],
#  170: [1, 5, 1, 2, 1, 1, 95],
#  218: [63, 1, 1, 1],
#  23: [4, 1, 1, 47, 29],
#  131: [21, 1, 32, 1, 1, 1],
#  551: [7, 1],
#  536: [1],
#  607: [1, 4],
#  568: [1],
#  221: [1, 1],
#  498: [15, 6],
#  361: [22, 32, 1, 1, 29],
#  463: [52, 1, 28, 1, 1, 1, 1, 1],
#  448: [1, 35],
#  436: [1, 6, 34],
#  422: [1],
#  208: [1, 43, 1, 99, 1],
#  301: [2],
#  110: [1, 1, 1, 29, 1, 30, 1, 1],
#  114: [1, 75, 1, 1, 1, 28, 1],
#  80: [1, 25, 14, 22, 1, 15, 24, 3, 1],
#  120: [20, 58, 26, 46, 15, 29, 1, 1, 43, 38, 1],
#  315: [40, 1, 1, 1],
#  285: [25, 1, 1, 4],
#  87: [46, 3, 1, 1, 25, 1],
#  506: [28],
#  77: [15, 16, 1, 39, 23, 1, 1, 10, 12],
#  46: [11, 22, 1, 16],
#  94: [1, 1],
#  149: [69, 1, 26],
#  132: [1, 30],
#  262: [31, 70, 1, 21],
#  215: [1, 41, 1, 1, 1],
#  577: [1],
#  339: [1, 1, 1],
#  143: [38, 1, 70, 6, 87],
#  99: [35, 46, 1],
#  153: [1, 1, 17, 52],
#  155: [20, 1, 27, 2, 41, 1, 1, 1, 1, 1, 1, 2, 1],
#  402: [19, 26, 43, 1, 1, 1, 18, 11],
#  174: [66, 2, 78, 64],
#  466: [7, 1],
#  573: [4, 1],
#  555: [7, 14, 1],
#  554: [1],
#  337: [22, 1, 18],
#  185: [65, 1],
#  271: [57, 1, 1, 1, 1, 1, 73],
#  266: [1, 75],
#  179: [77, 1, 1, 48, 1],
#  168: [1, 1, 1, 36],
#  217: [26, 53, 28, 6, 19],
#  200: [1, 3, 45],
#  125: [1, 63, 1],
#  618: [1],
#  425: [26],
#  364: [1, 1],
#  56: [39, 2, 18, 27, 1, 21],
#  397: [13],
#  389: [1],
#  464: [8],
#  327: [10],
#  235: [31, 1, 1, 93],
#  113: [1, 61],
#  160: [1, 1, 1, 37, 1, 38],
#  197: [1, 2, 63, 1, 1],
#  223: [1, 1],
#  24: [1, 1, 3, 8, 10, 4, 1, 7, 1],
#  338: [31, 81],
#  138: [1, 1, 49, 1, 98, 1, 56, 1, 29, 1],
#  36: [12, 15, 13, 7, 6, 11, 35, 1, 13],
#  490: [11, 1],
#  418: [1],
#  469: [1, 42, 1],
#  534: [10, 1],
#  48: [1, 1, 1, 7, 21, 4, 22],
#  676: [1],
#  674: [1, 1],
#  673: [1],
#  644: [1],
#  558: [8, 1, 1, 7],
#  314: [35, 1],
#  229: [1, 1, 1],
#  345: [47, 1, 1],
#  273: [27, 26, 1, 24],
#  226: [51, 2, 24, 28],
#  269: [1, 51, 3],
#  424: [24, 1, 24],
#  162: [32, 1, 46, 64, 46, 1],
#  253: [1, 1, 1, 45, 1, 45, 1, 1],
#  570: [6],
#  118: [2, 61, 1],
#  181: [29, 76, 2, 103, 1, 1, 1],
#  486: [18, 2],
#  88: [24, 1, 2],
#  440: [7],
#  343: [1],
#  513: [4, 2],
#  453: [29],
#  370: [1],
#  362: [36, 32],
#  32: [1, 8, 47, 1, 1],
#  152: [1, 1],
#  468: [1, 19],
#  53: [17, 16, 10, 17, 10, 1, 33, 1, 12],
#  203: [54, 2, 2, 47],
#  17: [1],
#  112: [45, 43, 1, 41, 1, 1, 1, 1, 44],
#  134: [1, 1, 54],
#  429: [21, 20, 1, 1, 1, 13],
#  378: [1, 1],
#  374: [1, 29, 1, 1],
#  178: [1, 1],
#  511: [14, 1],
#  545: [4],
#  139: [55, 66, 1],
#  158: [1, 32, 1],
#  137: [44, 97],
#  405: [28, 3],
#  376: [1, 1, 1, 29],
#  86: [13, 22, 1],
#  103: [58, 1, 1],
#  220: [1, 1, 30, 26],
#  230: [37, 26],
#  406: [41, 33, 2],
#  272: [1, 80, 1],
#  367: [52],
#  346: [1, 1],
#  342: [1, 1, 1, 1],
#  334: [1],
#  322: [1],
#  164: [30, 1],
#  308: [1, 1],
#  399: [20, 1, 31, 35],
#  691: [1],
#  157: [1, 1, 39, 1, 1, 68],
#  368: [18, 3, 2, 2, 2, 1, 1, 1],
#  247: [63, 44, 1, 1, 1, 96, 1, 1, 1],
#  102: [1, 1, 15, 1, 1],
#  344: [16],
#  325: [1, 28],
#  302: [1],
#  459: [25, 1, 1],
#  398: [1, 29, 1],
#  305: [2, 54, 1, 76, 1, 1, 1, 36],
#  3: [1],
#  193: [1, 104],
#  296: [39, 1],
#  126: [24, 48, 1, 1, 1, 1, 59],
#  278: [1, 1, 1],
#  350: [23],
#  525: [12],
#  371: [1, 1],
#  171: [87, 22, 1],
#  292: [11, 1],
#  246: [1, 29, 55, 1, 67],
#  384: [9, 1],
#  175: [1],
#  184: [1, 1, 28],
#  136: [1, 1, 2],
#  411: [1],
#  216: [1, 4, 1, 52, 55, 68, 1],
#  470: [17, 1, 1, 1],
#  622: [4, 1],
#  473: [18, 19, 1],
#  458: [1, 1],
#  312: [42, 37, 4],
#  206: [2, 1, 1, 1],
#  349: [19, 1],
#  319: [43, 1, 36],
#  482: [25],
#  403: [1],
#  81: [19, 37, 17, 1, 1],
#  194: [1, 41],
#  394: [1, 37],
#  416: [1],
#  401: [1, 1, 1],
#  581: [6],
#  199: [1, 52, 4],
#  476: [1, 1],
#  328: [55],
#  499: [10],
#  141: [1, 106, 1, 15, 1, 2, 1],
#  256: [1, 26, 1],
#  437: [1],
#  456: [1],
#  552: [10, 1, 1],
#  431: [8],
#  646: [1],
#  595: [5],
#  238: [61, 1],
#  683: [1],
#  351: [7, 29, 36],
#  304: [1, 1],
#  289: [71, 40],
#  634: [2],
#  393: [25, 48, 1, 2],
#  232: [37, 1, 1],
#  306: [1, 63, 1],
#  288: [1],
#  360: [1, 2, 1],
#  213: [35, 2, 19, 1, 65],
#  505: [9],
#  433: [5],
#  420: [1, 25],
#  130: [1],
#  64: [19, 2, 14, 1],
#  481: [2],
#  282: [59, 1],
#  214: [1],
#  412: [16, 1],
#  243: [2, 1, 42, 1, 37, 1, 29],
#  533: [14],
#  488: [23, 10, 1, 1, 1, 1],
#  553: [13, 1, 1],
#  663: [3],
#  380: [51, 1],
#  365: [1, 29, 1],
#  519: [15],
#  501: [12],
#  348: [71, 1, 1, 1],
#  417: [1],
#  651: [8],
#  653: [2],
#  142: [46, 1, 1],
#  539: [6],
#  619: [3],
#  572: [7],
#  518: [1],
#  183: [12, 1, 1, 6, 63, 1, 1],
#  205: [52],
#  447: [30, 1, 28],
#  561: [8, 10, 1, 1],
#  383: [1, 1],
#  379: [37, 1],
#  190: [2, 66, 1],
#  263: [28],
#  575: [3],
#  255: [1, 1],
#  480: [30, 1],
#  260: [1],
#  645: [1],
#  512: [1],
#  435: [1],
#  407: [1],
#  530: [1],
#  544: [11],
#  354: [30, 75],
#  462: [5, 1],
#  414: [19],
#  547: [8, 6, 1, 1, 1],
#  426: [17, 1, 1],
#  385: [1, 1],
#  535: [7],
#  228: [58],
#  307: [1],
#  309: [19],
#  491: [9, 1],
#  485: [1],
#  496: [1],
#  275: [41, 1, 1],
#  532: [2],
#  527: [1],
#  390: [1]}

# %%
final_df
# Out:
#           no                  id  flags       ref  for_pos  qual   cigar  \
# 0          0  SRR10199716.585733   1187  U00096.3     3340    60    138M
# 1          1  SRR10199716.199418   1187  U00096.3     3340    60    138M
# 2          2  SRR10199716.111533   1187  U00096.3     3340    60    138M
# 3          3  SRR10199716.240847   1187  U00096.3     3340    60  130M8S
# 4          4  SRR10199716.219410    163  U00096.3     3340    60    138M
# ...      ...                 ...    ...       ...      ...   ...     ...
# 86524  86545   SRR10199716.59475   1123  U00096.3  4634943    60    134M
# 86526  86547  SRR10199716.652277   1123  U00096.3  4634943    60    134M
# 86527  86548  SRR10199716.118008   1123  U00096.3  4634943    60    134M
# 86564  52219  SRR10199716.606725     99  U00096.3  3094094    49  75S59M
# 86569  70336  SRR10199716.592886   1123  U00096.3  4016876    60  66S68M
#
#       paired  rev_pos  length  for_count  rev_count  abs_length  counts  \
# 0          =     3713     507          6          6         507       2
# 1          =     3713     507          6          6         507       2
# 2          =     3713     507          6          6         507       2
# 3          =     3713     507          6          6         507       2
# 4          =     3713     507          6          6         507       2
# ...      ...      ...     ...        ...        ...         ...     ...
# 86524      =  4635048     243         33         31         243       2
# 86526      =  4635048     243         33         31         243       2
# 86527      =  4635048     243         33         31         243       2
# 86564      =  3094106     145          1          2         145       3
# 86569      =  4016834      96          1         68          96       3
#
#       for_mark rev_mark        unique_id
# 0         3340     3713        3340_3713
# 1         3340     3713        3340_3713
# 2         3340     3713        3340_3713
# 3         3340     3713        3340_3713
# 4         3340     3713        3340_3713
# ...        ...      ...              ...
# 86524  4634943  4635048  4634943_4635048
# 86526  4634943  4635048  4634943_4635048
# 86527  4634943  4635048  4634943_4635048
# 86564  3094094  3094106  3094094_3094106
# 86569  4016876  4016834  4016876_4016834
#
# [38970 rows x 17 columns]

# %%
final_dt = final_df['abs_length'].value_counts().to_dict()

# %%
plt.hist(final_dt.keys(), weights=final_dt.values(), bins=100)
plt.show()
